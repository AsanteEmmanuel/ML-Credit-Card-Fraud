# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

for dirname, _, filenames in os.walk('/Users/ea26/Desktop/MLP'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /Users/ea26/Desktop/MLP/.DS_Store
# /Users/ea26/Desktop/MLP/Untitled.ipynb
# /Users/ea26/Desktop/MLP/creditcard.csv
# /Users/ea26/Desktop/MLP/.ipynb_checkpoints/Untitled-checkpoint.ipynb

# %% [markdown]
# Import data into Pandas Dataframe

# %%
df = pd.read_csv('/Users/ea26/Desktop/MLP/creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# EDA and Data Preprocessing

# %%
# search for missing , NaN value and replace them
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.describe(include = "all").style.background_gradient(cmap = "summer")
# Out:
# <style type="text/css">
# #T_486f5_row0_col0, #T_486f5_row0_col1, #T_486f5_row0_col2, #T_486f5_row0_col3, #T_486f5_row0_col4, #T_486f5_row0_col5, #T_486f5_row0_col6, #T_486f5_row0_col7, #T_486f5_row0_col8, #T_486f5_row0_col9, #T_486f5_row0_col10, #T_486f5_row0_col11, #T_486f5_row0_col12, #T_486f5_row0_col13, #T_486f5_row0_col14, #T_486f5_row0_col15, #T_486f5_row0_col16, #T_486f5_row0_col17, #T_486f5_row0_col18, #T_486f5_row0_col19, #T_486f5_row0_col20, #T_486f5_row0_col21, #T_486f5_row0_col22, #T_486f5_row0_col23, #T_486f5_row0_col24, #T_486f5_row0_col25, #T_486f5_row0_col26, #T_486f5_row0_col27, #T_486f5_row0_col28, #T_486f5_row0_col29, #T_486f5_row0_col30 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_486f5_row1_col0 {
#   background-color: #55aa66;
#   color: #f1f1f1;
# }
# #T_486f5_row1_col1, #T_486f5_row1_col2, #T_486f5_row1_col3, #T_486f5_row1_col4, #T_486f5_row1_col5, #T_486f5_row1_col6, #T_486f5_row1_col7, #T_486f5_row1_col8, #T_486f5_row1_col9, #T_486f5_row1_col10, #T_486f5_row1_col11, #T_486f5_row1_col12, #T_486f5_row1_col13, #T_486f5_row1_col14, #T_486f5_row1_col15, #T_486f5_row1_col16, #T_486f5_row1_col17, #T_486f5_row1_col18, #T_486f5_row1_col19, #T_486f5_row1_col20, #T_486f5_row1_col21, #T_486f5_row1_col22, #T_486f5_row1_col23, #T_486f5_row1_col24, #T_486f5_row1_col25, #T_486f5_row1_col26, #T_486f5_row1_col27, #T_486f5_row1_col28, #T_486f5_row1_col29, #T_486f5_row1_col30, #T_486f5_row2_col1, #T_486f5_row2_col2, #T_486f5_row2_col3, #T_486f5_row2_col4, #T_486f5_row2_col5, #T_486f5_row2_col6, #T_486f5_row2_col7, #T_486f5_row2_col8, #T_486f5_row2_col9, #T_486f5_row2_col10, #T_486f5_row2_col11, #T_486f5_row2_col12, #T_486f5_row2_col13, #T_486f5_row2_col14, #T_486f5_row2_col15, #T_486f5_row2_col16, #T_486f5_row2_col17, #T_486f5_row2_col18, #T_486f5_row2_col19, #T_486f5_row2_col20, #T_486f5_row2_col21, #T_486f5_row2_col22, #T_486f5_row2_col23, #T_486f5_row2_col24, #
_col19, #T_486f5_row6_col20, #T_486f5_row6_col21, #T_486f5_row6_col22, #T_486f5_row6_col23, #T_486f5_row6_col24, #T_486f5_row6_col25, #T_486f5_row6_col26, #T_486f5_row6_col27, #T_486f5_row6_col28, #T_486f5_row6_col29, #T_486f5_row6_col30, #T_486f5_row7_col1, #T_486f5_row7_col2, #T_486f5_row7_col3, #T_486f5_row7_col4, #T_486f5_row7_col5, #T_486f5_row7_col6, #T_486f5_row7_col7, #T_486f5_row7_col8, #T_486f5_row7_col9, #T_486f5_row7_col10, #T_486f5_row7_col11, #T_486f5_row7_col12, #T_486f5_ro ...
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_486f5_row2_col0 {
#   background-color: #2a9466;
#   color: #f1f1f1;
# }
# #T_486f5_row4_col0 {
#   background-color: #309866;
#   color: #f1f1f1;
# }
# #T_486f5_row5_col0 {
#   background-color: #4ca666;
#   color: #f1f1f1;
# }
# #T_486f5_row6_col0 {
#   background-color: #7dbe66;
#   color: #000000;
# }
# #T_486f5_row7_col0 {
#   background-color: #9bcd66;
#   color: #000000;
# }
# #T_486f5_row7_col29 {
#   background-color: #178b66;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_486f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_486f5_level0_col0" class="col_heading level0 col0" >Time</th>
#       <th id="T_486f5_level0_col1" class="col_heading level0 col1" >V1</th>
#       <th id="T_486f5_level0_col2" class="col_heading level0 col2" >V2</th>
#       <th id="T_486f5_level0_col3" class="col_heading level0 col3" >V3</th>
#       <th id="T_486f5_level0_col4" class="col_heading level0 col4" >V4</th>
#       <th id="T_486f5_level0_col5" class="col_heading level0 col5" >V5</th>
#       <th id="T_486f5_level0_col6" class="col_heading level0 col6" >V6</th>
#       <th id="T_486f5_level0_col7" class="col_heading level0 col7" >V7</th>
#       <th id="T_486f5_level0_col8" class="col_heading level0 col8" >V8</th>
#       <th id="T_486f5_level0_col9" class="col_heading level0 col9" >V9</th>
#       <th id="T_486f5_level0_col10" class="col_heading level0 col10" >V10</th>
#       <th id="T_486f5_level0_col11" class="col_heading level0 col11" >V11</th>
#       <th id="T_486f5_level0_col12" class="col_heading level0 col12" >V12</th>
#       <th id="T_486f5_level0_col13" class="col_heading level0 col13" >V13</th>
#       <th id="T_486f5_level0_col14" class="col_heading level0 col14" >V14</th>
#       <th id="T_486f5_level0_col15" class="col_heading level0 col15" >V15</th>
#       <th id="T_486f5_level0_col16" class="col_heading level0 col16" >V16</th>
#       <th id="T_486f5_level0_col17" class="col_heading level0 col17" >V17</th>
#       <th id="T_486f5_level0_col18" class="col_heading level0 col18" >V18</th>
#       <th id="T_486f5_level0_col19" class="col_heading level0 col19" >V19</th>
#       <th id="T_486f5_level0_col20" class="col_heading level0 col20" >V20</th>
#       <th id="T_486f5_level0_col21" class="col_heading level0 col21" >V21</th>
#       <th id="T_486f5_level0_col22" class="col_heading level0 col22" >V22</th>
#       <th id="T_486f5_level0_col23" class="col_heading level0 col23" >V23</th>
#       <th id="T_486f5_level0_col24" class="col_heading level0 col24" >V24</th>
#       <th id="T_486f5_level0_col25" class="col_heading level0 col25" >V25</th>
#       <th id="T_486f5_level0_col26" class="col_heading level0 col26" >V26</th>
#       <th id="T_486f5_level0_col27" class="col_heading level0 col27" >V27</th>
#       <th id="T_486f5_level0_col28" class="col_heading level0 col28" >V28</th>
#       <th id="T_486f5_level0_col29" class=

# %%
# Eliminate duplicate records

# %%
df.duplicated().sum()
df.drop_duplicates(inplace = True)

# %%
df_train = df

# %%
y = df['Class']

# %%
X = df_train

# %%
# Scale the data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

scaled_data = scaler.fit_transform(X)

scaled_X = pd.DataFrame(scaled_data, columns = X.columns)

# %%
scaled_X.describe(include = "all").style.background_gradient(cmap = "summer")
# Out:
# <style type="text/css">
# #T_aba76_row0_col0, #T_aba76_row0_col1, #T_aba76_row0_col2, #T_aba76_row0_col3, #T_aba76_row0_col4, #T_aba76_row0_col5, #T_aba76_row0_col6, #T_aba76_row0_col7, #T_aba76_row0_col8, #T_aba76_row0_col9, #T_aba76_row0_col10, #T_aba76_row0_col11, #T_aba76_row0_col12, #T_aba76_row0_col13, #T_aba76_row0_col14, #T_aba76_row0_col15, #T_aba76_row0_col16, #T_aba76_row0_col17, #T_aba76_row0_col18, #T_aba76_row0_col19, #T_aba76_row0_col20, #T_aba76_row0_col21, #T_aba76_row0_col22, #T_aba76_row0_col23, #T_aba76_row0_col24, #T_aba76_row0_col25, #T_aba76_row0_col26, #T_aba76_row0_col27, #T_aba76_row0_col28, #T_aba76_row0_col29, #T_aba76_row0_col30 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_aba76_row1_col0, #T_aba76_row1_col1, #T_aba76_row1_col2, #T_aba76_row1_col3, #T_aba76_row1_col4, #T_aba76_row1_col5, #T_aba76_row1_col6, #T_aba76_row1_col7, #T_aba76_row1_col8, #T_aba76_row1_col9, #T_aba76_row1_col10, #T_aba76_row1_col11, #T_aba76_row1_col12, #T_aba76_row1_col13, #T_aba76_row1_col14, #T_aba76_row1_col15, #T_aba76_row1_col16, #T_aba76_row1_col17, #T_aba76_row1_col18, #T_aba76_row1_col19, #T_aba76_row1_col20, #T_aba76_row1_col21, #T_aba76_row1_col22, #T_aba76_row1_col23, #T_aba76_row1_col24, #T_aba76_row1_col25, #T_aba76_row1_col26, #T_aba76_row1_col27, #T_aba76_row1_col28, #T_aba76_row1_col29, #T_aba76_row1_col30, #T_aba76_row2_col0, #T_aba76_row2_col1, #T_aba76_row2_col2, #T_aba76_row2_col3, #T_aba76_row2_col4, #T_aba76_row2_col5, #T_aba76_row2_col6, #T_aba76_row2_col7, #T_aba76_row2_col8, #T_aba76_row2_col9, #T_aba76_row2_col10, #T_aba76_row2_col11, #T_aba76_row2_col12, #T_aba76_row2_col13, #T_aba76_row2_col14, #T_aba76_row2_col15, #T_aba76_row2_col16, #T_aba76_row2_col17, #T_aba76_row2_col18, #T_aba76_row2_col19, #T_aba76_row2_col20, #T_aba76_row2_col21, #T_aba76_row2_col22,
6_col14, #T_aba76_row6_col15, #T_aba76_row6_col16, #T_aba76_row6_col17, #T_aba76_row6_col18, #T_aba76_row6_col19, #T_aba76_row6_col20, #T_aba76_row6_col21, #T_aba76_row6_col22, #T_aba76_row6_col23, #T_aba76_row6_col24, #T_aba76_row6_col25, #T_aba76_row6_col26, #T_aba76_row6_col27, #T_aba76_row6_col28, #T_aba76_row6_col29, #T_aba76_row6_col30, #T_aba76_row7_col0, #T_aba76_row7_col1, #T_aba76_row7_col2, #T_aba76_row7_col3, #T_aba76_row7_col4, #T_aba76_row7_col5, #T_aba76_row7_col6, #T_aba76_row7_ ...
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_aba76">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aba76_level0_col0" class="col_heading level0 col0" >Time</th>
#       <th id="T_aba76_level0_col1" class="col_heading level0 col1" >V1</th>
#       <th id="T_aba76_level0_col2" class="col_heading level0 col2" >V2</th>
#       <th id="T_aba76_level0_col3" class="col_heading level0 col3" >V3</th>
#       <th id="T_aba76_level0_col4" class="col_heading level0 col4" >V4</th>
#       <th id="T_aba76_level0_col5" class="col_heading level0 col5" >V5</th>
#       <th id="T_aba76_level0_col6" class="col_heading level0 col6" >V6</th>
#       <th id="T_aba76_level0_col7" class="col_heading level0 col7" >V7</th>
#       <th id="T_aba76_level0_col8" class="col_heading level0 col8" >V8</th>
#       <th id="T_aba76_level0_col9" class="col_heading level0 col9" >V9</th>
#       <th id="T_aba76_level0_col10" class="col_heading level0 col10" >V10</th>
#       <th id="T_aba76_level0_col11" class="col_heading level0 col11" >V11</th>
#       <th id="T_aba76_level0_col12" class="col_heading level0 col12" >V12</th>
#       <th id="T_aba76_level0_col13" class="col_heading level0 col13" >V13</th>
#       <th id="T_aba76_level0_col14" class="col_heading level0 col14" >V14</th>
#       <th id="T_aba76_level0_col15" class="col_heading level0 col15" >V15</th>
#       <th id="T_aba76_level0_col16" class="col_heading level0 col16" >V16</th>
#       <th id="T_aba76_level0_col17" class="col_heading level0 col17" >V17</th>
#       <th id="T_aba76_level0_col18" class="col_heading level0 col18" >V18</th>
#       <th id="T_aba76_level0_col19" class="col_heading level0 col19" >V19</th>
#       <th id="T_aba76_level0_col20" class="col_heading level0 col20" >V20</th>
#       <th id="T_aba76_level0_col21" class="col_heading level0 col21" >V21</th>
#       <th id="T_aba76_level0_col22" class="col_heading level0 col22" >V22</th>
#       <th id="T_aba76_level0_col23" class="col_heading level0 col23" >V23</th>
#       <th id="T_aba76_level0_col24" class="col_heading level0 col24" >V24</th>
#       <th id="T_aba76_level0_col25" class="col_heading level0 col25" >V25</th>
#       <th id="T_aba76_level0_col26" class="col_heading level0 col26" >V26</th>
#       <th id="T_aba76_level0_col27" class="col_heading level0 col27" >V27</th>
#       <th id="T_aba76_level0_col28" class="col_heading level0 col28" >V28</th>
#       <th id="T_aba76_level0_col29" class="col_heading level0 col29" >Amount</th>
#       <th id="T_aba76_level0_col30" class="col_heading level0 col30" >Class</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aba76_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_aba76_row0_col0" class="data row0 col0" >283726.000000</td>
#       <td id="T_aba76_row0_col1" c

# %%
# Step here: Balance our dataset since the fraud records are only 473

# %%
scaled_X['Class'].value_counts() # clearly this is an imbalanced data
# Out:
# 0.0    283253
# 1.0       473
# Name: Class, dtype: int64

# %%
scaled_X.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
# get the fraud and non-fraud records
normal = scaled_X[scaled_X['Class'] == 0]
fraud = scaled_X[scaled_X['Class'] == 1]

# get samples from the majority class # downsampling in this case 50-50 classes
normal_sample = normal.sample(n = 473)
df = pd.concat([normal_sample, fraud], axis = 0)
df
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 260464  0.926038  0.957216  0.777964  0.821246  0.227511  0.776520  0.251804
# 170971  0.698690  0.992492  0.776247  0.783327  0.310999  0.777092  0.257911
# 43566   0.240972  0.979854  0.760195  0.858139  0.227570  0.755453  0.257522
# 128625  0.456948  0.982702  0.754643  0.846122  0.190892  0.754626  0.255891
# 33934   0.217018  0.925674  0.758653  0.827267  0.328971  0.794196  0.238271
# ...          ...       ...       ...       ...       ...       ...       ...
# 278813  0.978876  0.925541  0.779136  0.759117  0.329475  0.755171  0.242806
# 279090  0.980063  0.981714  0.780863  0.750697  0.314516  0.768696  0.249683
# 279096  0.980086  0.946807  0.779143  0.799053  0.272690  0.758173  0.262986
# 280081  0.983645  0.905394  0.773440  0.743844  0.332480  0.760057  0.233425
# 280611  0.985856  0.992135  0.768931  0.792646  0.270046  0.773466  0.262048
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 260464  0.274040  0.782472  0.444945  ...  0.562157  0.515598  0.659063
# 170971  0.268200  0.783299  0.454343  ...  0.562273  0.524296  0.661404
# 43566   0.259174  0.785236  0.443136  ...  0.568928  0.572283  0.665000
# 128625  0.258836  0.784039  0.407121  ...  0.555480  0.469985  0.666954
# 33934   0.263197  0.784321  0.430986  ...  0.562499  0.493924  0.665763
# ...          ...       ...       ...  ...       ...       ...       ...
# 278813  0.259977  0.792864  0.391646  ...  0.574031  0.495141  0.674930
# 279090  0.256746  0.788051  0.423943  ...  0.567454  0.511348  0.663271
# 279096  0.251741  0.798367  0.440311  ...  0.573599  0.548942  0.668269
# 280081  0.251904  0.796742  0.406549  ...  0.570882  0.497472  0.658660
# 280611  0.266714  0.784652  0.482685  ...  0.558830  0.496263  0.664362
#
#              V24       V25       V26       V27       V28    Amount  Class
# 260464  0.438587  0.609877  0.541708  0.414977  0.313330  0.000046    0.0
# 170971  0.150709  0.605506  0.366703  0.417397  0.313322  0.000898    0.0
# 43566   0.473052  0.595165  0.416187  0.417581  0.313772  0.000973    0.0
# 128625  0.377254  0.585703  0.361618  0.417049  0.313792  0.002335    0.0
# 33934   0.270069  0.587316  0.380423  0.415136  0.313905  0.000039    0.0
# ...          ...       ...       ...       ...       ...       ...    ...
# 278813  0.342499  0.608078  0.554231  0.421913  0.316127  0.015180    1.0
# 279090  0.371313  0.607201  0.546239  0.423694  0.316911  0.000030    1.0
# 279096  0.386556  0.536386  0.502403  0.423619  0.317068  0.003032    1.0
# 280081  0.357486  0.559486  0.524456  0.432844  0.307976  0.009536    1.0
# 280611  0.321562  0.595491  0.378140  0.416566  0.312813  0.001655    1.0
#
# [946 rows x 31 columns]

# %% [markdown]
# # Data Visualisation
#  Create a correlation heatmap to highlight relationships between features

# %%
import seaborn as sns
plt.figure(figsize = (30, 18))
sns.heatmap(df.corr(), cmap = "summer", annot = True, square = True, )
plt.show()

# %% [markdown]
# It seems that there may be some informative relationship between class vs {V14, V17, V4}. also it may be worth exploring the pairwise relationships between members of the set {V9, V10} and {V16, V17, V18}
# creating a boxplot to see whether v14 or Amount has a distinct effect on the transactioons nature i.e. fraud or normal

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#
selected_features = ['V4', 'V17']

# Create box plots for selected features
plt.figure(figsize=(12, 6))
for feature in selected_features:
    plt.subplot(1, len(selected_features), selected_features.index(feature) + 1)
    sns.boxplot(x='Class', y=feature, data=df)
    plt.title(f'Box Plot of {feature}')
    plt.xlabel('Class (0: Non-Fraud, 1: Fraud)')
    plt.ylabel(feature)
    
plt.tight_layout()
plt.show()

# %%
#
selected_features = ['Amount', 'V14']

# Create box plots for selected features
plt.figure(figsize=(12, 6))
for feature in selected_features:
    plt.subplot(1, len(selected_features), selected_features.index(feature) + 1)
    sns.boxplot(x='Class', y=feature, data=df)
    plt.title(f'Box Plot of {feature}')
    plt.xlabel('Class (0: Non-Fraud, 1: Fraud)')
    plt.ylabel(feature)
    
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='V16', y='V17', hue='Class', data=df)
plt.title('Scatter Plot of V16 vs V17 with Class Hue')
plt.xlabel('V16')
plt.ylabel('V17')
plt.legend(title='Class', loc='upper right')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='V14', y='Amount', hue='Class', data=df)
plt.title('Scatter Plot of V14 vs Amount with Class Hue')
plt.xlabel('V14')
plt.ylabel('Amount')
plt.legend(title='Class', loc='upper right')
plt.show()

# %% [markdown]
# Because of the correlations between the some of the features, it is worth exploring PCA.

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

X = df.drop('Class', axis = 1)
y = df['Class']

pca = PCA(n_components = 2)
X_pca = pca.fit_transform(X)

# create a new dataframe to visualize
pca_df = pd.DataFrame(X_pca, columns = ['PC1', 'PC2'])
pca_df['Class'] = y

# Create scatter plot of PCA components
plt.figure(figsize=(10, 6))
sns.scatterplot(x='PC1', y='PC2', hue='Class', data=pca_df, palette='Set1')
plt.title('PCA Visualization of Credit Card Fraud Detection Data')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Class')
plt.show()

# %%
y = df['Class']
df.drop('Class', axis = 1)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 260464  0.926038  0.957216  0.777964  0.821246  0.227511  0.776520  0.251804
# 170971  0.698690  0.992492  0.776247  0.783327  0.310999  0.777092  0.257911
# 43566   0.240972  0.979854  0.760195  0.858139  0.227570  0.755453  0.257522
# 128625  0.456948  0.982702  0.754643  0.846122  0.190892  0.754626  0.255891
# 33934   0.217018  0.925674  0.758653  0.827267  0.328971  0.794196  0.238271
# ...          ...       ...       ...       ...       ...       ...       ...
# 278813  0.978876  0.925541  0.779136  0.759117  0.329475  0.755171  0.242806
# 279090  0.980063  0.981714  0.780863  0.750697  0.314516  0.768696  0.249683
# 279096  0.980086  0.946807  0.779143  0.799053  0.272690  0.758173  0.262986
# 280081  0.983645  0.905394  0.773440  0.743844  0.332480  0.760057  0.233425
# 280611  0.985856  0.992135  0.768931  0.792646  0.270046  0.773466  0.262048
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 260464  0.274040  0.782472  0.444945  ...  0.578731  0.562157  0.515598
# 170971  0.268200  0.783299  0.454343  ...  0.580246  0.562273  0.524296
# 43566   0.259174  0.785236  0.443136  ...  0.581576  0.568928  0.572283
# 128625  0.258836  0.784039  0.407121  ...  0.577487  0.555480  0.469985
# 33934   0.263197  0.784321  0.430986  ...  0.589520  0.562499  0.493924
# ...          ...       ...       ...  ...       ...       ...       ...
# 278813  0.259977  0.792864  0.391646  ...  0.593606  0.574031  0.495141
# 279090  0.256746  0.788051  0.423943  ...  0.582673  0.567454  0.511348
# 279096  0.251741  0.798367  0.440311  ...  0.582906  0.573599  0.548942
# 280081  0.251904  0.796742  0.406549  ...  0.583526  0.570882  0.497472
# 280611  0.266714  0.784652  0.482685  ...  0.580077  0.558830  0.496263
#
#              V23       V24       V25       V26       V27       V28    Amount
# 260464  0.659063  0.438587  0.609877  0.541708  0.414977  0.313330  0.000046
# 170971  0.661404  0.150709  0.605506  0.366703  0.417397  0.313322  0.000898
# 43566   0.665000  0.473052  0.595165  0.416187  0.417581  0.313772  0.000973
# 128625  0.666954  0.377254  0.585703  0.361618  0.417049  0.313792  0.002335
# 33934   0.665763  0.270069  0.587316  0.380423  0.415136  0.313905  0.000039
# ...          ...       ...       ...       ...       ...       ...       ...
# 278813  0.674930  0.342499  0.608078  0.554231  0.421913  0.316127  0.015180
# 279090  0.663271  0.371313  0.607201  0.546239  0.423694  0.316911  0.000030
# 279096  0.668269  0.386556  0.536386  0.502403  0.423619  0.317068  0.003032
# 280081  0.658660  0.357486  0.559486  0.524456  0.432844  0.307976  0.009536
# 280611  0.664362  0.321562  0.595491  0.378140  0.416566  0.312813  0.001655
#
# [946 rows x 30 columns]

# %% [markdown]
# split the data into training and test set and model.

# %%
from sklearn.model_selection import train_test_split as split
X_train, X_test, y_train, y_test = split(df, y, test_size = 0.2, random_state = 42)
y
# Out:
# 260464    0.0
# 170971    0.0
# 43566     0.0
# 128625    0.0
# 33934     0.0
#          ...
# 278813    1.0
# 279090    1.0
# 279096    1.0
# 280081    1.0
# 280611    1.0
# Name: Class, Length: 946, dtype: float64

# %%
# Model Creation and Evaluation
